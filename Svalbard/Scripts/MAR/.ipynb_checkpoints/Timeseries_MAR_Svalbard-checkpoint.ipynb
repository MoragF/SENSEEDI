# %%
import xarray as xr
import numpy as np
import scipy.io as io
import matplotlib.pyplot as plt
import pandas as pd
from netCDF4 import Dataset as netcdf

# %%
from affine import Affine
tif = xr.open_rasterio('/home/s1423313/Documents/Svalbard/Regions/Region_Masks/07_rgi60_Svalbard_corr_land_R1.tif')

# %%
ncfile = netcdf('/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/MARv3.11.2-6km-daily-ERA5-2001.nc')
ncfile.variables
#ds= xr.open_dataset('/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/MARv3.11.2-6km-daily-ERA5-2001.nc')
#ds
# Out:
# OrderedDict([('X20_340', <class 'netCDF4._netCDF4.Variable'>
#               float32 X20_340(X20_340)
#                   units: km
#                   long_name: x
#                   point_spacing: even
#                   axis: X
#               unlimited dimensions:
#               current shape = (321,)
#               filling off), ('Y20_218', <class 'netCDF4._netCDF4.Variable'>
#               float32 Y20_218(Y20_218)
#                   units: km
#                   long_name: y
#                   point_spacing: even
#                   axis: Y
#               unlimited dimensions:
#               current shape = (199,)
#               filling off), ('LON', <class 'netCDF4._netCDF4.Variable'>
#               float32 LON(Y20_218, X20_340)
#                   units: degrees
#                   long_name: Longitude
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('LAT', <class 'netCDF4._netCDF4.Variable'>
#               float32 LAT(Y20_218, X20_340)
#                   units: degrees
#                   long_name: Latitude
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('SH', <class 'netCDF4._netCDF4.Variable'>
#               float32 SH(Y20_218, X20_340)
#                   units: m
#                   long_name: Surface Height
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('SRF', <class 'netCDF4._netCDF4.Variable'>
#               float32 SRF(Y20_218, X20_340)
#                   units: -
#                   long_name: Surface Type
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('MSK', <class 'netCDF4._netCDF4.Variable'>
#               float32 MSK(Y20_218, X20_340)
#                   units: -
#                   long_name: Ice Sheet Area
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('SECTOR', <class 'netCDF4._netCDF4.Variable'>
#               float32 SECTOR(SECTOR)
#                   units: level
#                   long_name: sector
#                   positive: down
#                   point_spacing: even
#                   axis: Z
#                   standard_name: depth
#               unlimited dimensions:
#               current shape = (2,)
#               filling off), ('FRV', <class 'netCDF4._netCDF4.Variable'>
#               float32 FRV(SECTOR, Y20_218, X20_340)
#                   units: %
#                   long_name: Vegetation Class Coverage
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (2, 199, 321)
#               filling off), ('VEG', <class 'netCDF4._netCDF4.Variable'>
#               float32 VEG(SECTOR, Y20_218, X20_340)
#                   units: -
#                   long_name: Vegetation Type Index
#                   history: From ICE.x42.2020.01.01-05
#               unlimited dimensions:
#               current shape = (2, 199, 321)
#               filling off), ('AREA', <class 'netCDF4._netCDF4.Variable'>
#               float64 AREA(Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: area
#                   history: From fort.999
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('MASK', <class 'netCDF4._netCDF4.Variable'>
#               float64 MASK(Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: MASK1+MASK2+MASK3+MASK4
#                   history: From MAR-GRx.nc2
#               unlimited dimensions:
#               current shape = (199, 321)
#               filling off), ('TIME', <class 'netCDF4._netCDF4.Variable'>
#               float32 TIME(TIME)
#                   units: days since 1998-09-01 00:00:00
#                   long_name: time
#                   time_origin: 01-SEP-1998 00:00:00
#                   axis: T
#                   standard_name: time
#               unlimited dimensions: TIME
#               current shape = (365,)
#               filling off), ('DATE', <class 'netCDF4._netCDF4.Variable'>
#               float32 DATE(TIME)
#                   units: YYYYMMDDHH
#                   long_name: Date(YYYY MM DD HH)
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365,)
#               filling off), ('cnst', <class 'netCDF4._netCDF4.Variable'>
#               float64 cnst()
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: constant
#               unlimited dimensions:
#               current shape = ()
#               filling off), ('MM', <class 'netCDF4._netCDF4.Variable'>
#               float32 MM(TIME)
#                   units: YYYYMMDDHH
#                   long_name: Date(YYYY MM DD HH)
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365,)
#               filling off), ('DD', <class 'netCDF4._netCDF4.Variable'>
#               float32 DD(TIME)
#                   units: YYYYMMDDHH
#                   long_name: Date(YYYY MM DD HH)
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365,)
#               filling off), ('SECTOR1_1', <class 'netCDF4._netCDF4.Variable'>
#               float32 SECTOR1_1(SECTOR1_1)
#                   units: level
#                   long_name: sector
#                   positive: down
#                   point_spacing: even
#                   axis: Z
#                   standard_name: depth
#               unlimited dimensions:
#               current shape = (1,)
#               filling off), ('SMB', <class 'netCDF4._netCDF4.Variable'>
#               float32 SMB(TIME, SECTOR1_1, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Surface Mass Balance (SMB~SF+RF-RU-SU-SW)
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('RU', <class 'netCDF4._netCDF4.Variable'>
#               float32 RU(TIME, SECTOR1_1, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Run-off of meltwater and rain water
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('SF', <class 'netCDF4._netCDF4.Variable'>
#               float32 SF(TIME, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Snowfall
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 199, 321)
#               filling off), ('RF', <class 'netCDF4._netCDF4.Variable'>
#               float32 RF(TIME, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Rainfall
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 199, 321)
#               filling off), ('ME', <class 'netCDF4._netCDF4.Variable'>
#               float32 ME(TIME, SECTOR1_1, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Meltwater production
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('SU', <class 'netCDF4._netCDF4.Variable'>
#               float32 SU(TIME, SECTOR1_1, Y20_218, X20_340)
#                   missing_value: -1e+34
#                   _FillValue: -1e+34
#                   long_name: Sublimation and evaporation
#                   units: mmWE/day
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('ZN4', <class 'netCDF4._netCDF4.Variable'>
#               float32 ZN4(TIME, SECTOR1_1, Y20_218, X20_340)
#                   units: m
#                   long_name: Snowheight change due to compac
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('ZN5', <class 'netCDF4._netCDF4.Variable'>
#               float32 ZN5(TIME, SECTOR1_1, Y20_218, X20_340)
#                   units: m
#                   long_name: Snowheight change due to melt
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off), ('ZN6', <class 'netCDF4._netCDF4.Variable'>
#               float32 ZN6(TIME, SECTOR1_1, Y20_218, X20_340)
#                   units: m
#                   long_name: Total snowheight change
#                   history: From ICE.x23.2001.01.01-05
#               unlimited dimensions: TIME
#               current shape = (365, 1, 199, 321)
#               filling off)])

# %%
ncfile = netcdf('/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/Svalbard_Masked/Svalbard_MR2.nc')
ncfile.variables
# Out:
# OrderedDict([('time', <class 'netCDF4._netCDF4.Variable'>
#               float64 time(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('smb_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 smb_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('rf_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 rf_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('sf_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 sf_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('ru_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 ru_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('su_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 su_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('sh_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 sh_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('me_mean', <class 'netCDF4._netCDF4.Variable'>
#               float64 me_mean(time)
#               unlimited dimensions:
#               current shape = (6939,)
#               filling on, default _FillValue of 9.969209968386869e+36 used)])

# %%
ds.smb_mean.sel(time=slice('2010-07-18','2016-12-31')).plot()

# %%
def MARplot(matfile,ncfile,title,npng):
    ds= xr.open_dataset(ncfile)
    ds['time']= pd.date_range('2001-01-01','2019-12-31')
    SMB= ds.smb_mean
    RF=ds.rf_mean

    matdata=io.loadmat(matfile)
    elevation = matdata['Tmsr'][0]
    t = matdata['time'][0]
    timepy= pd.to_datetime(t-719529, unit='D')
    E_ds = xr.Dataset(data_vars = dict(elev= (["t"],elevation)),coords=dict(t=timepy))

    labels = ['Elevation Land', 'MAR: SMB','MAR: RF','MAR: RF','MAR: RF','MAR: RF']
    fig, (ax1, ax2, ax3) = plt.subplots(3,figsize=(18,10), sharex=True)
    plt.suptitle(title, fontsize=16)

    color = 'tab:red'
    ax1.set_ylabel('elevation[m]', color=color, fontsize=14)
    ax1.plot(E_ds.t, E_ds.elev, color=color)

    color = 'tab:blue'
    ax2.set_ylabel('kg m$^{2}$', color=color, fontsize=14)  # we already handled the x-label with ax1
    ax2.plot(SMB.time.sel(time=slice('2010-07-18','2019-12-31')), SMB.sel(time=slice('2010-07-18','2019-12-31')).cumsum(), color=color)

    color = 'tab:green'
    ax3.set_ylabel('mmWE/day', color=color, fontsize=14)  
    ax3.plot(RF.time.sel(time=slice('2010-07-18','2019-12-31')), RF.sel(time=slice('2010-07-18','2019-12-31')), color=color)
    ax3.plot(SF.time.sel(time=slice('2010-07-18','2019-12-31')), SF.sel(time=slice('2010-07-18','2019-12-31')), color=color)

    color = 'tab:green'
    ax4.set_ylabel('mmWE/day', color=color, fontsize=14)  
    ax4.plot(SU.time.sel(time=slice('2010-07-18','2019-12-31')), SU.sel(time=slice('2010-07-18','2019-12-31')), color=color)
    ax4.plot(RU.time.sel(time=slice('2010-07-18','2019-12-31')), RU.sel(time=slice('2010-07-18','2019-12-31')), color=color)

    
    fig.legend(labels)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
    plt.savefig(npng)
    plt.show()

# %%
ds= xr.open_dataset('/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/Svalbard_Masked/Svalbard_MR2.nc')
ds['time']= pd.date_range('2001-01-01','2019-12-31')
SMB= ds.smb_mean
SMB
# Out:
# <xarray.DataArray 'smb_mean' (time: 6939)>
# array([0.938341, 2.248414, 0.423771, ..., 0.07456 , 0.025511, 0.028343])
# Coordinates:
#   * time     (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2019-12-31

# %%
for i in range(1,7):
    MARplot('/geos/d14/CS2/dhdt/Timeseries/Svalbard_LR'+str(i)+'_MF/tmsr_45_90_07_rgi60_Svalbard_corr_land_R'+str(i)+'.mat','/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/Svalbard_Masked/Svalbard_LR'+str(i)+'.nc','Svalbard Land R'+str(i),'Svalbard_LR'+str(i)+'.png')

# %%
for i in range(2,3):
    MARplot('/geos/d14/CS2/dhdt/Timeseries/Svalbard_MR'+str(i)+'_MF/tmsr_45_90_07_rgi60_Svalbard_corr_marine_R'+str(i)+'.mat','/exports/csce/datastore/geos/groups/geos_EO/Databases/MAR/Svalbard-RA/Svalbard_Masked/Svalbard_MR'+str(i)+'.nc','Svalbard Land R'+str(i),'Svalbard_MR'+str(i)+'.png')

# %%
fig, ax1 = plt.subplots(figsize=(18,10))

color = 'tab:red'
ax1.set_xlabel('time')
ax1.set_ylabel('elevation[m]', color=color)
ax1.plot(MAR_data.time, MAR_data.elevation_Aus_land, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('mmWE/day', color=color)  # we already handled the x-label with ax1
ax2.plot(timeseries.TIME.sel(TIME=slice('2010-07-18','2019-12-31')), timeseries.sel(TIME=slice('2010-07-18','2019-12-31')), color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.legend(labels)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.figure(figsize=(18,10))
plt.show()
